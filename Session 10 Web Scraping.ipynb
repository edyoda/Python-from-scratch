# %%
Beautiful Soup => library 
Scrapy framework

# %%
cleint browser www.magicbricks.com   request  get/post                                 server

# %%
to get data from server get 
to send some data and receive some data  => Post

# %%
html page => data

# %%
<html>
    <head>
        <title></title>
        <meta></meta>
        <link></link>
        <script></script>
    <head>
    
    <body>
        <div>
        <p> This is a sample text</p>
        <a href="www.google.com">click here</a>
        </div>
    </body>

</html>

# %%
requests
beautifulsoup

# %%
import random

# %%
pip install requests 
pip install BeautifulSoup4

# %%
import requests 
from bs4 import BeautifulSoup

# %%
response = requests.get("https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment&cityName=Bangalore")

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.content)
# Out:
# b'\n<!DOCTYPE html>\n<html>\n<head>\n<meta charset="UTF-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="google-signin-client_id" content="614944930403-u1s9tmqebd273mutmdhmsngnhvivgd6a.apps.googleusercontent.com">\n<link rel="dns-prefetch preconnect" href="//cdn.staticmb.com"/>\n<link rel="dns-prefetch preconnect" href="//img.staticmb.com"/>\n<link rel="dns-prefetch preconnect" href="//b.scorecardresearch.com">\n<link rel="dns-prefetch preconnect" href="//www.googleadservices.com">\n<link rel="dns-prefetch preconnect" href="//stats.g.doubleclick.net">\n<link rel="dns-prefetch preconnect" href="//ase.clmbtech.com">\n<link rel="dns-prefetch preconnect" href="//ingestor.magicbricks.com">\n<link rel="dns-prefetch preconnect" href="//maps.googleapis.com">\n<link rel="dns-prefetch preconnect" href="//www.googletagmanager.com">\n<title>29896 Flats for Sale in Bangalore | MagicBricks</title>
# ...

# %%
404 page not found 
500 Internal Server error
401 403 Unauthorised 
200 OK /success 
Http status code

# %%
soup = BeautifulSoup(response.content,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="614944930403-u1s9tmqebd273mutmdhmsngnhvivgd6a.apps.googleusercontent.com" name="google-signin-client_id"/>
# <link href="//cdn.staticmb.com" rel="dns-prefetch preconnect"/>
# <link href="//img.staticmb.com" rel="dns-prefetch preconnect"/>
# <link href="//b.scorecardresearch.com" rel="dns-prefetch preconnect"/>
# <link href="//www.googleadservices.com" rel="dns-prefetch preconnect"/>
# <link href="//stats.g.doubleclick.net" rel="dns-prefetch preconnect"/>
# <link href="//ase.clmbtech.com" rel="dns-prefetch preconnect"/>
# <link href="//ingestor.magicbricks.com" rel="dns-prefetch preconnect"/>
# <link href="//maps.googleapis.com" rel="dns-prefetch preconnect"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch preconnect"/>
# ...

# %%
find("a") => first link 
find_all => all occrances of link 

find_parent 
find_parents 

find_sibling
find_siblings

# %%
1 Top to bottom => find find_all 
2 bottom to top => find_parent find_parents 
3 sideways =>  find_sibling find_siblings

# %%
price = soup.find("div",attrs ={"class":"m-srp-card__price"})
print(price.text)
# Out:
# ₹ 54 Lac

# %%
prices = soup.find_all("div",attrs ={"class":"m-srp-card__price"})
# print(prices)
for price in prices:
    print(price.text)
# Out:
# ₹ 54 Lac
# ₹ 74.5 Lac
# ₹ 92.9 Lac
# ₹ 69 Lac
# ₹ 1.10 Cr
# ₹ 1.49 Cr
# ₹ 64.8 Lac
# ₹ 36 Lac
# ₹ 78.5 Lac
# ₹ 68.6 Lac
# ₹ 69.8 Lac
# ₹ 93.8 Lac
# ₹ 1.02 Cr
# ₹ 47.8 Lac
# ₹ 45.3 Lac
# ₹ 1.15 Cr
# ₹ 78.5 Lac
# ₹ 27.5 Lac
# ₹ 94 Lac
# ₹ 1 Cr
# ₹ 1.75 Cr
# ₹ 64.5 Lac
# ₹ 60.7 Lac
# ₹ 82.5 Lac
# ₹ 75 Lac
# ₹ 3.90 Cr
# ₹ 85.5 Lac
# ₹ 44.8 Lac
# ₹ 51.9 Lac
# ₹ 41.3 Lac
# ₹ 1.20 Cr

# %%
card = soup.find("div",attrs ={"class":"m-srp-card__container"})
price = card.find("div",attrs ={"class":"m-srp-card__price"}) 
title = card.find("a",attrs = {"class":"m-srp-card__title"})
# print(title.get("href"))
response2 = requests.get(title.get("href"))
soup2 = BeautifulSoup(response2.content,"html.parser")
agent_name = soup2.find("p",attrs = {"class":"CA_agent_name"})
# print(agent_name.text)
# print(response2)

title_text = title.text.replace("\n"," ")
area = card.find("div",attrs = {"class":"m-srp-card__summary__info"})
print("{} {} {} {}".format(title_text,area.text,price.text,agent_name.text))
# Out:
#   2 BHK Flat  for Sale in Kasturi Nagar  1050 sqft ₹ 54 Lac
# APNA GHAR

# %%
cards = soup.find_all("div",attrs ={"class":"m-srp-card__container"})
for card in cards:
    price = card.find("div",attrs ={"class":"m-srp-card__price"}) 
    title = card.find("a",attrs = {"class":"m-srp-card__title"})
    response2 = requests.get(title.get("href"))
    soup2 = BeautifulSoup(response2.content,"html.parser")
    agent_name = soup2.find("p",attrs = {"class":"CA_agent_name"})
    title_text = title.text.replace("\n"," ")
    area = card.find("div",attrs = {"class":"m-srp-card__summary__info"})
    print("{} {} {} {}".format(title_text,area.text,price.text,agent_name.text))
# Out:
#   2 BHK Flat  for Sale in Kasturi Nagar  1050 sqft ₹ 54 Lac
# APNA GHAR
#
#   3 BHK Flat  for Sale in Kogilu  1732 sqft ₹ 74.5 Lac
# Gautam
#
#   3 BHK Flat  for Sale in Jp Nagar Phase 7, J P Nagar  1600 sqft ₹ 92.9 Lac
# Gayathri
#
#   2 BHK Flat  for Sale in Thanisandra Main Road  1040 sqft ₹ 69 Lac
# Reji
#
#   3 BHK Flat  for Sale in Jakkur, Thanisandra  1773 sqft ₹ 1.10 Cr
# Prime Homes
#
#   3 BHK Flat  for Sale in Yeshwantpur  1680 sqft ₹ 1.49 Cr
# Deccangroup
#
#   2 BHK Flat  for Sale in Harlur  1167 sqft ₹ 64.8 Lac
# Nagaraja Reddy
#
#   2 BHK Flat  for Sale in Devanahalli  885 sqft ₹ 36 Lac
# Shyam
#
#   3 BHK Flat  for Sale in Whitefield  1600 sqft ₹ 78.5 Lac
# Ajay Kumar
#
#   2 BHK Flat  for Sale in Electronics City Phase 1, Electronic City  1248 sqft ₹ 68.6 Lac
# Gopalan
#
#   2 BHK Flat  for Sale in Yelahanka  1047 sqft ₹ 69.8 Lac
# Shibu
#
#   3 BHK Flat  for Sale in Jp Nagar Phase 8  1400 sqft ₹ 93.8 Lac
# Mary
#
# ...
