# %%
str

# %%
for [var] in [iterable datatype]:
    statemnts

# %%
range(5) : 0...4
range(10,55) 10 11 ... 54 
range(10,25,2) : 10 12 14 .. 24
    
for index,value in enumerate(l):

# %%
while [condition]:
    statemnts

# %%
if []:
    print("Python")
else:
    print("Java")

# %%
list 
set 
tuple 
str 
dict

# %%
Str: 
    - ' ' " " """ """
    - immutable = > no methods to add update and delete
    - ordered => indexing and slicing

# %%
s = """  "Python" 
sample string """
print(s)
# Out:
#   "Python"
# sample string

# %%
s = "Python sample string"
print(s[8])
print(s[-12])
print(s[100])
# Out:
# a
# a
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-b367d66e7567> in <module>()
#       2 print(s[8])
#       3 print(s[-12])
# ----> 4 print(s[100])
#
# IndexError: string index out of range

# %%
s = "Python sample string"
# print(s[0:6])
# print(s[7:])
# print(s[:6])
# print(s[0:10:1])
# print(s[::-1])
# print(s[8::-1])
# print(s[5::-2])
# Out:
# nhy

# %%
stride = > 
1 Alternate chars 
2 Direction +ve => left to right 
            -ve => right to left

# %%
s = "madam"
if s == s[::-1]:
    print("Palindrome")
else:
    print("Not palindrome")
# Out:
# Palindrome

# %%
s1 = "Python"
s2 = '100'
s3 = s1 +s2
print(s3)
# Out:
# Python100

# %%
s1 = "Python"
print(s1 * 3)
# Out:
# PythonPythonPython

# %%
s1 = "Python"
s2 = "java"
print(s1 - s2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-e881792da6fd> in <module>()
#       1 s1 = "Python"
#       2 s2 = "java"
# ----> 3 print(s1 - s2)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> str
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
num1 = 100
num2 = 200
num3 = num1 + num2

s = "first number is {}, second number is {} and the additions is {}".format(num1,num2,num3)
print(s)
# Out:
# first number is 100, second number is 200 and the additions is 300

# %%
s = "python,java,c,c++,R"
l = s.split(",")
print(l)
s1 = (" ").join(l)
print(s1)
# Out:
# ['python', 'java', 'c', 'c++', 'R']
# python java c c++ R

# %%
s = "python,java,c,c++,R"
l = s.split(",")
print(l)
l2 = l[::-1]
print(l2)
s2 = (",").join(l2)
print(s2)
# Out:
# ['python', 'java', 'c', 'c++', 'R']
# ['R', 'c++', 'c', 'java', 'python']
# R,c++,c,java,python

# %%
index 
find 
replace 
count

# %%
s = "python,java,c,c++,python,java"
print(s.index("R"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-12d1460eb702> in <module>()
#       1 s = "python,java,c,c++,python,java"
# ----> 2 print(s.index("R"))
#
# ValueError: substring not found

# %%
s = "python,java,c,c++,python,java"
print(s.find("R"))
# Out:
# -1

# %%
s = "python,java,c,c++,python,java"
print(id(s))
s = s.replace("python","python 3.7")
print(id(s))
print(s)
# Out:
# 1650310353344
# 1650309342640
# python 3.7,java,c,c++,python 3.7,java

# %%
"python"   344  
"python 3.7" 640  s

# %%
s = "python,java,c,c++,python,java"
print(s.count("java"))
# Out:
# 2

# %%
s = "python sample string"
for x in s:
    print(x,end = " ")
# Out:
# p y t h o n   s a m p l e   s t r i n g

# %%
l = [10,20,30,40,50,60]
for x in l:
    print(x)

# %%
print(10 , 20,end = " ")
print("Hi",end = " ")
print("Python")
# Out:
# 10 20 Hi Python

# %%
upper isupper 
lower  islower
title istitle 
capitalize

# %%
s = "python sample string"
s1 = s1.upper()
print(s1)
print(s.isupper())
# Out:
# PYTHON SAMPLE STRING
# False

# %%
s = "Python Sample String"
s1 =  s.lower()
print(s1)
# Out:
# python sample string

# %%
s = "pyThon saMple StrIng"
s1 =  s.title()
print(s1.istitle())
# Out:
# True

# %%
s = "pyThon saMple StrIng"
s1 =  s.capitalize()
print(s1)
# Out:
# Python sample string

# %%
s1 = "Python sample string"
if s1[0].isupper() and s1[1:].islower():
    print(True)
else:
    print(False)
# Out:
# True

# %%
s1 = "Python sample string"
print(s1.capitalize())
if s1 == s1.capitalize():
    print(True)
else:
    print(False)
# Out:
# Python sample string
# True

# %%
center 
ljust 
rjust 

strip 
lstrip 
rstrip

# %%
s = "python"
s1 = s.center(21,"*")
print(s1)
# Out:
#         python

# %%
s = "python"
s1 = s.ljust(21,"*")
print(s1)
# Out:
# python***************

# %%
s = "python"
s1 = s.rjust(21,"*")
print(s1)
# Out:
# ***************python

# %%
strip
lstrip
rstrip

# %%
s = "python"
s1 = s.center(21,"*")
print(s1)
# Out:
# ********python*******

# %%
s2 = s1.strip("*")
print(s2)
# Out:
# python

# %%
s2 = s1.rstrip("*")
print(s2)
# Out:
# ********python

# %%
isalpha
isalnum
isspace 
isdigit

# %%
s = "abc"
# print(s.isalpha())
# print(s.isdigit())
# print(s.isalnum())
# print(s.isspace())
# Out:
# False

# %%
help(str)

# %%
print(dir(str))

# %%
count 
find -1
replace 
index error

center 
ljust
rjust 

strip 
lstrip
rstrip 

capitalize 
upper isupper
lower islower
title istitle 


isalpha 
isalnum
isdigit
isspace 

split str => list 
join list => str

"{} {}".format

# %%
s = "Java,Python,Django"
print(s[2:6:-2])
